# %% [markdown]
# # Prediction using Deep Learning
#
# Insurance companies take risks over customers. Risk management is a very important aspect of the insurance industry. Insurers consider every quantifiable factor to develop profiles of high and low insurance risks. Insurers collect vast amounts of information about policyholders and analyse the data. As a Data scientist in an insurance company, you need to analyse the available data and predict whether to approve the insurance or not.

# %% [markdown]
# #Author: Mohit T. Kumbhare And Pranay D. Sonkusare
#
# ## Date: 17 Jan 2022

# %%
# Importing libraries
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split

from sklearn.preprocessing import StandardScaler

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Load Data

# %%
df = pd.read_csv('/content/drive/MyDrive/Deep Learning/Project/data.csv')

# %%
df.head()
# Out:
#       ID Agency    Agency Type  ... Commision (in value) Gender  Age
# 0   3433    CWT  Travel Agency  ...                17.82    NaN   31
# 1   4339    EPX  Travel Agency  ...                 0.00    NaN   36
# 2  34590    CWT  Travel Agency  ...                11.88    NaN   75
# 3  55816    EPX  Travel Agency  ...                 0.00    NaN   32
# 4  13816    EPX  Travel Agency  ...                 0.00    NaN   29
#
# [5 rows x 12 columns]

# %%
# Checking Any Null or unwanted Values 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50553 entries, 0 to 50552
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   ID                    50553 non-null  int64
#  1   Agency                50553 non-null  object
#  2   Agency Type           50553 non-null  object
#  3   Distribution Channel  50553 non-null  object
#  4   Product Name          50553 non-null  object
#  5   Claim                 50553 non-null  int64
#  6   Duration              50553 non-null  int64
#  7   Destination           50553 non-null  object
#  8   Net Sales             50553 non-null  float64
#  9   Commision (in value)  50553 non-null  float64
#  10  Gender                14600 non-null  object
#  11  Age                   50553 non-null  int64
# dtypes: float64(2), int64(4), object(6)
# memory usage: 4.6+ MB

# %%
df.describe()
# Out:
#                  ID         Claim  ...  Commision (in value)           Age
# count  50553.000000  50553.000000  ...           50553.00000  50553.000000
# mean   31679.740134      0.014658  ...               9.83809     40.011236
# std    18288.265350      0.120180  ...              19.91004     14.076566
# min        0.000000      0.000000  ...               0.00000      0.000000
# 25%    15891.000000      0.000000  ...               0.00000     35.000000
# 50%    31657.000000      0.000000  ...               0.00000     36.000000
# 75%    47547.000000      0.000000  ...              11.55000     44.000000
# max    63325.000000      1.000000  ...             283.50000    118.000000
#
# [8 rows x 6 columns]

# %%
df['Claim'].value_counts()
# Out:
# 0    49812
# 1      741
# Name: Claim, dtype: int64

# %%
# Spliting into feature and target
X = df.drop('Claim', axis = 1)
y = df['Claim']

# %%
# Seperating numerical and categorical data
df_num = X.select_dtypes(['int64', 'float64'])
df_cat = X.select_dtypes(['object'])

# %%
df_num.head()
# Out:
#    Duration  Net Sales  Commision (in value)  Age
# 0         7        0.0                 17.82   31
# 1        85       69.0                  0.00   36
# 2        11       19.8                 11.88   75
# 3        16       20.0                  0.00   32
# 4        10       15.0                  0.00   29

# %%
# replace nan value with unknown
df_cat['Gender'].replace(np.nan, 'Unknown', inplace = True)
df_cat['Gender'].value_counts()
# Out:
# Unknown    35953
# M           7527
# F           7073
# Name: Gender, dtype: int64

# %%
for i in df_cat:
  plt.figure(figsize=(20,8))
  sns.countplot(data=df_cat, x=i)
  plt.title(i)
  plt.xticks(rotation = 90)
  plt.show()

# %%
df_cat.head()
# Out:
#   Agency    Agency Type  ...         Destination   Gender
# 0    CWT  Travel Agency  ...            MALAYSIA  Unknown
# 1    EPX  Travel Agency  ...           SINGAPORE  Unknown
# 2    CWT  Travel Agency  ...            MALAYSIA  Unknown
# 3    EPX  Travel Agency  ...           INDONESIA  Unknown
# 4    EPX  Travel Agency  ...  KOREA, REPUBLIC OF  Unknown
#
# [5 rows x 6 columns]

# %%
# One-Hot encoding
df_cat = pd.get_dummies(df_cat)

# %%
df_num.head()
# Out:
#       ID  Duration  Net Sales  Commision (in value)  Age
# 0   3433         7        0.0                 17.82   31
# 1   4339        85       69.0                  0.00   36
# 2  34590        11       19.8                 11.88   75
# 3  55816        16       20.0                  0.00   32
# 4  13816        10       15.0                  0.00   29

# %%
df_num = df_num.drop('ID', axis = 1)

# %%
# Concat numerical and categorical data
X = pd.concat([df_num, df_cat], axis = 1)

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y, test_size=0.3, random_state=1)

# %%
data = ['Duration',	'Net Sales',	'Commision (in value)',	'Age']
ss = StandardScaler()
for i in data:
  X_train[i] = ss.fit_transform(X_train[[i]])
  X_test[i] = ss.transform(X_test[[i]])

# %%
X_train.shape
# Out:
# (35387, 154)

# %%
# Architecture
model = Sequential()
model.add(Dense(32, activation="tanh", input_dim=154))
# model.add(Dense(32, activation="tanh"))
model.add(Dense(16, activation="tanh"))
model.add(Dense(16, activation="tanh"))
model.add(Dense(8, activation="tanh"))
model.add(Dense(8, activation="tanh"))
model.add(Dense(4, activation="tanh"))
model.add(Dense(2, activation="tanh"))
model.add(Dense(1, activation="sigmoid"))

# %%
model.compile(optimizer="adam", loss="binary_crossentropy")

# %%
# Over Sampling
from imblearn.over_sampling import RandomOverSampler
rs = RandomOverSampler(random_state=1)
X_train_rs, y_train_rs = rs.fit_resample(X_train,y_train)

# %%
y_train_rs.value_counts()
# Out:
# 1    34851
# 0    34851
# Name: Claim, dtype: int64

# %%
model.fit(X_train_rs,y_train_rs, batch_size=128, epochs=30)
# Out:
# Epoch 1/30
# 545/545 [==============================] - 2s 3ms/step - loss: 0.5502
# Epoch 2/30
# 545/545 [==============================] - 1s 2ms/step - loss: 0.4861
# Epoch 3/30
# 545/545 [==============================] - 1s 3ms/step - loss: 0.4744
# Epoch 4/30
# 545/545 [==============================] - 1s 2ms/step - loss: 0.4673
# Epoch 5/30
# 545/545 [==============================] - 1s 2ms/step - loss: 0.4625
# Epoch 6/30
# 545/545 [==============================] - 1s 2ms/step - loss: 0.4595
# Epoch 7/30
# 545/545 [==============================] - 1s 2ms/step - loss: 0.4543
# Epoch 8/30
# 545/545 [==============================] - 1s 2ms/step - loss: 0.4524
# Epoch 9/30
# 545/545 [==============================] - 1s 2ms/step - loss: 0.4490
# Epoch 10/30
# 545/545 [==============================] - 1s 2ms/step - loss: 0.4472
# Epoch 11/30
# 545/545 [==============================] - 1s 2ms/step - loss: 0.4442
# Epoch 12/30
# 545/545 [==============================] - 1s 2ms/step - loss: 0.4428
# Epoch 13/30
# 545/545 [==============================] - 1s 2ms/step - loss: 0.4401
# Epoch 14/30
# 545/545 [==============================] - 1s 2ms/step - loss: 0.4376
# Epoch 15/30
# 545/545 [==============================] - 1s 2ms/step - loss: 0.4351
# Epoch 16/30
# 545/545 [==============================] - 1s 2ms/step - loss: 0.4326
# Epoch 17/30
# 545/545 [==============================] - 1s 2ms/step - loss: 0.4271
# Epoch 18/30
# 545/545 [==============================] - 1s 2ms/step - loss: 0.4204
# Epoch 19/30
# 545/545 [==============================] - 1s 2ms/step - loss: 0.4125
# Epoch 20/30
# 545/545 [==============================] - 1s 2ms/step - loss: 0.4055
# Epoch 21/30
# 545/545 [==============================] - 1s 2ms/step - loss: 0.3970
# Epoch 22/30
# 545/545 [==============================] - 1s 2ms/step - loss: 0.3788
# Epoch 23/30
# 545/545 [==============================] - 1s 2ms/step - loss: 0.3651
# Epoch 24/30
# 545/545 [==============================] - 1s 2ms/step - loss: 0.3563
# Epoch 25/30
# 545/545 [==============================] - 1s 3ms/step - loss: 0.3467
# Epoch 26/30
# 545/545 [==============================] - 1s 3ms/step - loss: 0.3397
# Epoch 27/30
# 545/545 [==============================] - 1s 2ms/step - loss: 0.3319
# Epoch 28/30
# 545/545 [==============================] - 1s 2ms/step - loss: 0.3243
# Epoch 29/30
# 545/545 [==============================] - 1s 2ms/step - loss: 0.3162
# Epoch 30/30
# 545/545 [==============================] - 1s 2ms/step - loss: 0.3121

# %%
y_pred = model.predict(X_test)

# %%
y_pred = np.where(y_pred >= 0.5, 1, 0)

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.86      0.92     14961
#            1       0.05      0.51      0.09       205
#
#     accuracy                           0.86     15166
#    macro avg       0.52      0.69      0.51     15166
# weighted avg       0.98      0.86      0.91     15166
